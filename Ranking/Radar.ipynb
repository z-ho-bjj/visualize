# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.cm import ScalarMappable
from textwrap import wrap
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import pandas as pd
import numpy as np
from math import pi

# %%
df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

# %%
categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# polar그래프 그리기
ax = plt.subplot(111, polar=True)
 
# 등분점에 맞게 그리기
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# y라벨 그리기
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 

ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'b', alpha=0.1)

plt.show()

# %%
categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
 
# 첫번째 그룹
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
# 두번째 그룹
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)
 
# 세번째 그룹
values=df.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group C")
ax.fill(angles, values, 'g', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.2))

gl = ax.yaxis.get_gridlines()
for g in gl:
    g.get_path()._interpolation_steps = N

plt.show()

# %%
def make_spider( row, title, color):

    categories=list(df)[1:]
    N = len(categories)

    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    ax = plt.subplot(2,2,row+1, polar=True, )

    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    plt.xticks(angles[:-1], categories, color='grey', size=8)

    ax.set_rlabel_position(0)
    plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
    plt.ylim(0,40)

    values=df.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    plt.title(title, size=11, color=color, y=1.1)

# %%
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 
# 색상 파레트
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# 루프로 그리기
for row in range(0, len(df.index)):
    make_spider( row=row, title='group '+df['group'][row], color=my_palette(row))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10788\2053340898.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   my_palette = plt.cm.get_cmap("Set2", len(df.index))

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi

df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)

for i in range(len(df)):
    values=df.loc[i].drop('group').values.flatten().tolist()
    g_nm = df['group'][i]
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='dashdot', label=f"group {g_nm}") # linestyle : dashed, solid, dashdot, dotted --> '-' / '--' / '-.' / ':'
    ax.fill(angles, values, alpha=0.1)

plt.legend(loc='upper right', bbox_to_anchor=(1.2,1.2))
plt.show()

# %%
import rpy2.robjects as robjects

# %%
readRDS=robjects.r['readRDS']
df = readRDS('./hike_data.rds')

# %%
list(df.colnames)
# Out:
# ['name',
#  'location',
#  'length',
#  'gain',
#  'highpoint',
#  'rating',
#  'features',
#  'description']

# %%
data = pd.DataFrame(df)
data=data.T

# %%
data.columns = list(df.colnames)

# %%
data["region"] = data["location"].str.split("--", n=1, expand=True)[0]
data["region"] = data["region"].str.strip()

# %%
data["length_num"] = data["length"].str.split(" ", n=1, expand=True)[0].astype(float)

# %%
type(data['gain'][0])
# Out:
# str

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958 entries, 0 to 1957
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1958 non-null   object
#  1   location     1958 non-null   object
#  2   length       1958 non-null   object
#  3   gain         1958 non-null   object
#  4   highpoint    1958 non-null   object
#  5   rating       1958 non-null   object
#  6   features     1958 non-null   object
#  7   description  1958 non-null   object
#  8   region       1958 non-null   object
#  9   length_num   1958 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 153.1+ KB

# %%
data
# Out:
#                                      name  \
# 0                    Lake Hills Greenbelt
# 1                               Snow Lake
# 2                           Skookum Flats
# 3                         Teneriffe Falls
# 4                              Twin Falls
# ...                                   ...
# 1953                          Smith Creek
# 1954                          Slate Creek
# 1955  Boulder Creek - Gallagher Head Lake
# 1956            Silver Star View Snowshoe
# 1957                       Snowgrass Flat
#
#                                                location  \
# 0        Puget Sound and Islands -- Seattle-Tacoma Area
# 1                  Snoqualmie Region -- Snoqualmie Pass
# 2          Mount Rainier Area -- Chinook Pass - Hwy 410
# 3                  Snoqualmie Region -- North Bend Area
# 4                  Snoqualmie Region -- North Bend Area
# ...                                                 ...
# 1953                 South Cascades -- Mount St. Helens
# ...

# %%
data['gain'] = pd.to_numeric(data['gain'])
data['highpoint'] = pd.to_numeric(data['highpoint'])
data['rating'] = pd.to_numeric(data['rating'])

# %%
summary_stats = data.groupby(["region"]).agg(sum_length = ("length_num", "sum"),
                                             mean_gain = ("gain", "mean")).reset_index()

summary_stats["mean_gain"] = summary_stats["mean_gain"].round(0)

trackNrs = data.groupby("region").size().to_frame('n').reset_index()

# %%
summary_all = pd.merge(summary_stats, trackNrs, "left", on = "region")

# %%
summary_all
# Out:
#                      region  sum_length  mean_gain    n
# 0          Central Cascades     2130.85     2260.0  226
# 1        Central Washington      453.30      814.0   80
# 2        Eastern Washington     1333.64     1591.0  143
# 3             Issaquah Alps      383.11      973.0   77
# 4        Mount Rainier Area     1601.80     1874.0  196
# 5            North Cascades     3346.53     2500.0  301
# 6         Olympic Peninsula     1699.91     1572.0  209
# 7   Puget Sound and Islands      810.34      452.0  191
# 8         Snoqualmie Region     1915.32     2206.0  219
# 9            South Cascades     1630.32     1649.0  193
# 10     Southwest Washington      825.02     1185.0  123

# %%
# 정렬
df_sorted = summary_all.sort_values("sum_length", ascending=False)

ANGLES = np.linspace(0.05, 2 * np.pi - 0.05, len(df_sorted), endpoint=False) # x축 값
LENGTHS = df_sorted["sum_length"].values # 누적길이
MEAN_GAIN = df_sorted["mean_gain"].values # 평균길이
REGION = df_sorted["region"].values # 레이블
TRACKS_N = df_sorted["n"].values # 트랙 수

# %%
GREY12 = "#1f1f1f"

plt.rcParams.update({"font.family": "Bell MT"}) # 글꼴
plt.rcParams["text.color"] = GREY12 # 색상

# Bell MT 글꼴에서는 마이너스 못씀, 그래서 minus를 False시키면 하이픈으로 대체됨
plt.rc("axes", unicode_minus=False)

COLORS = ["#6C5B7B","#C06C84","#F67280","#F8B195"]
cmap = mpl.colors.LinearSegmentedColormap.from_list("my color", COLORS, N=256)
norm = mpl.colors.Normalize(vmin=TRACKS_N.min(), vmax=TRACKS_N.max())

COLORS = cmap(norm(TRACKS_N))

# %%
fig, ax = plt.subplots(figsize=(9, 12.6), subplot_kw={"projection": "polar"})

fig.patch.set_facecolor("white")
ax.set_facecolor("white")

ax.set_theta_offset(1.2 * np.pi / 2)
ax.set_ylim(-1500, 3500)

ax.bar(ANGLES, LENGTHS, color=COLORS, alpha=0.9, width=0.52, zorder=10)
ax.vlines(ANGLES, 0, 3000, color=GREY12, ls=(0, (4, 4)), zorder=11)
ax.scatter(ANGLES, MEAN_GAIN, s=60, color=GREY12, zorder=11)

REGION = ["\n".join(wrap(r, 5, break_long_words=False)) for r in REGION]


ax.set_xticks(ANGLES)
ax.set_xticklabels(REGION, size=12)
ax.xaxis.grid(False)


ax.set_yticklabels([])
ax.set_yticks([0, 1000, 2000, 3000])

ax.spines["start"].set_color("none")
ax.spines["polar"].set_color("none")

XTICKS = ax.xaxis.get_major_ticks()
for tick in XTICKS:
    tick.set_pad(10)

PAD = 10
ax.text(-0.2 * np.pi / 2, 1000 + PAD, "1000", ha="center", size=12)
ax.text(-0.2 * np.pi / 2, 2000 + PAD, "2000", ha="center", size=12)
ax.text(-0.2 * np.pi / 2, 3000 + PAD, "3000", ha="center", size=12)

ax.text(ANGLES[0], 3100, "Cummulative Length [FT]", rotation=21, 
        ha="center", va="center", size=10, zorder=12)
ax.text(ANGLES[0]+ 0.012, 1300, "Mean Elevation Gain\n[FASL]", rotation=-69, 
        ha="center", va="center", size=10, zorder=12)

fig.subplots_adjust(bottom=0.175)

cbaxes = inset_axes(
    ax, 
    width="100%", 
    height="100%", 
    loc="center",
    bbox_to_anchor=(0.325, 0.1, 0.35, 0.01),
    bbox_transform=fig.transFigure 
) 

bounds = [0, 100, 150, 200, 250, 300]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

# 컬러바 만들기
cb = fig.colorbar(
    ScalarMappable(norm=norm, cmap=cmap), 
    cax=cbaxes, 
    orientation = "horizontal",
    ticks=[100, 150, 200, 250]
)

cb.outline.set_visible(False)
cb.ax.xaxis.set_tick_params(size=0)
cb.set_label("Amount of tracks", size=12, labelpad=-40)

# annotations 추가
fig.subplots_adjust(top=0.8)

# title, subtitle, and caption 지정
title = "\nHiking Locations in Washington"
subtitle = "\n".join([
    "This Visualisation shows the cummulative length of tracks,",
    "the amount of tracks and the mean gain in elevation per location.\n",
    "If you are an experienced hiker, you might want to go",
    "to the North Cascades since there are a lot of tracks,",
    "higher elevations and total length to overcome."
])
caption = "Data Visualisation by Tobias Stalder\ntobias-stalder.netlify.app\nSource: TidyX Crew (Ellis Hughes, Patrick Ward)\nLink to Data: github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-11-24/readme.md"

fig.text(0.1, 0.93, title, fontsize=25, weight="bold", ha="left", va="baseline")
fig.text(0.1, 0.9, subtitle, fontsize=14, ha="left", va="top")
fig.text(0.5, 0.025, caption, fontsize=10, ha="center", va="baseline")
# Out:
# Text(0.5, 0.025, 'Data Visualisation by Tobias Stalder\ntobias-stalder.netlify.app\nSource: TidyX Crew (Ellis Hughes, Patrick Ward)\nLink to Data: github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-11-24/readme.md')

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)


df = pd.DataFrame({
'group': ['B'],
'안정성': [28],
'편리성': [19],
'경제성': [35],
'특성 A': [15],
'특성 B': [30]
})
# df = pd.DataFrame({
# 'group': ['A','B','C','D'],
# 'var1': [38, 1.5, 30, 4],
# 'var2': [29, 10, 9, 34],
# 'var3': [8, 39, 23, 24],
# 'var4': [7, 31, 33, 14],
# 'var5': [28, 15, 32, 14]
# })

categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.xticks(fontsize=20, fontweight='bold')
plt.ylim(0,40)

for i in range(len(df)):
    values=df.loc[i].drop('group').values.flatten().tolist()
    g_nm = df['group'][i]
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='dashdot', label=f"충전소 {g_nm}",color='orange') # linestyle : dashed, solid, dashdot, dotted --> '-' / '--' / '-.' / ':'
    
    ax.tick_params(axis='x', which='major', pad=15)
    ax.fill(angles, values, alpha=0.1,color='orange')

spine = Spine(axes=ax,
          spine_type='circle',
          path=Path.unit_regular_polygon(len(categories)))
 
## Axes의 중심과 반지름을 맞춰준다.
spine.set_transform(Affine2D().scale(.5).translate(.5, .5)+ax.transAxes)
           
ax.spines = {'polar':spine} ## frame의 모양을 원에서 폴리곤으로 바꿔줘야한다.

# plt.legend(loc='upper right', bbox_to_anchor=(1.2,1.2))
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)


df = pd.DataFrame({
'group': ['B'],
'안정성': [28],
'편리성': [19],
'효율성': [35],
'특성 A': [15],
'특성 B': [30]
})
# df = pd.DataFrame({
# 'group': ['A','B','C','D'],
# 'var1': [38, 1.5, 30, 4],
# 'var2': [29, 10, 9, 34],
# 'var3': [8, 39, 23, 24],
# 'var4': [7, 31, 33, 14],
# 'var5': [28, 15, 32, 14]
# })

categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)

for i in range(len(df)):
    values=df.loc[i].drop('group').values.flatten().tolist()
    g_nm = df['group'][i]
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='dashdot', label=f"충전소 {g_nm}",color='orange') # linestyle : dashed, solid, dashdot, dotted --> '-' / '--' / '-.' / ':'
    plt.xticks(fontsize=20)
    ax.tick_params(axis='x', which='major', pad=15)
    ax.fill(angles, values, alpha=0.1,color='orange')

spine = Spine(axes=ax,
          spine_type='circle',
          path=Path.unit_regular_polygon(len(labels)))
 
## Axes의 중심과 반지름을 맞춰준다.
spine.set_transform(Affine2D().scale(.5).translate(.5, .5)+ax.transAxes)
           
ax.spines = {'polar':spine} ## frame의 모양을 원에서 폴리곤으로 바꿔줘야한다.

# plt.legend(loc='upper right', bbox_to_anchor=(1.2,1.2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Admin\Desktop\Z-Ho\Z-Ho_Project\2023\visualize\Ranking\Radar.ipynb Cell 26 in 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Z-Ho/Z-Ho_Project/2023/visualize/Ranking/Radar.ipynb#X34sZmlsZQ%3D%3D?line=61'>62</a>     ax.tick_params(axis='x', which='major', pad=15)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Z-Ho/Z-Ho_Project/2023/visualize/Ranking/Radar.ipynb#X34sZmlsZQ%3D%3D?line=62'>63</a>     ax.fill(angles, values, alpha=0.1,color='orange')
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Z-Ho/Z-Ho_Project/2023/visualize/Ranking/Radar.ipynb#X34sZmlsZQ%3D%3D?line=64'>65</a> spine = Spine(axes=ax,
# ...
