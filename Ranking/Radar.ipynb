# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from math import pi

# %%
df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

# %%
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
angles
# Out:
# [0.0,
#  1.2566370614359172,
#  2.5132741228718345,
#  3.7699111843077517,
#  5.026548245743669,
#  0.0]

# %%
ax = plt.subplot(111, polar=True)
plt.xticks(angles[:-1], categories, color='grey', size=8)
# Out:
# ([<matplotlib.projections.polar.ThetaTick at 0x24aba533ee0>,
#   <matplotlib.projections.polar.ThetaTick at 0x24aba4f5d30>,
#   <matplotlib.projections.polar.ThetaTick at 0x24aba533f40>,
#   <matplotlib.projections.polar.ThetaTick at 0x24aba546a00>,
#   <matplotlib.projections.polar.ThetaTick at 0x24aba54d6a0>],
#  [Text(0.0, 0, 'var1'),
#   Text(1.2566370614359172, 0, 'var2'),
#   Text(2.5132741228718345, 0, 'var3'),
#   Text(3.7699111843077517, 0, 'var4'),
#   Text(5.026548245743669, 0, 'var5')])

# %%
categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# polar그래프 그리기
ax = plt.subplot(111, polar=True)
 
# 등분점에 맞게 그리기
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# y라벨 그리기
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 

ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'b', alpha=0.1)

plt.show()

# %%
categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
 
# 첫번째 그룹
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
# 두번째 그룹
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)
 
# 세번째 그룹
values=df.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group C")
ax.fill(angles, values, 'g', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.2))

plt.show()

# %%
def make_spider( row, title, color):

    categories=list(df)[1:]
    N = len(categories)

    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    ax = plt.subplot(2,2,row+1, polar=True, )

    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    plt.xticks(angles[:-1], categories, color='grey', size=8)

    ax.set_rlabel_position(0)
    plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
    plt.ylim(0,40)

    values=df.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    plt.title(title, size=11, color=color, y=1.1)

# %%
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 
# 색상 파레트
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# 루프로 그리기
for row in range(0, len(df.index)):
    make_spider( row=row, title='group '+df['group'][row], color=my_palette(row))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10788\2053340898.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   my_palette = plt.cm.get_cmap("Set2", len(df.index))

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi

df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

categories=list(df)[1:]
N = len(categories)
 
# 레이더 차트 그릴 리스트 만들기
# values += values[:1]은 원순열이 되어 이어져야하기 때문에 처음 값을 한번 더 더함
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]

 
# 등분점
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)

ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 

plt.xticks(angles[:-1], categories)
 

ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)

for i in range(len(df)):
    values=df.loc[i].drop('group').values.flatten().tolist()
    g_nm = df['group'][i]
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='dashdot', label=f"group {g_nm}") # linestyle : dashed, solid, dashdot, dotted --> '-' / '--' / '-.' / ':'
    ax.fill(angles, values, alpha=0.1)

plt.legend(loc='upper right', bbox_to_anchor=(1.2,1.2))
plt.show()
