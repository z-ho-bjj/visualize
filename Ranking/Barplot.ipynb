# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patheffects import withStroke
from matplotlib import lines
from matplotlib import rc
import seaborn as sns

# %%
height = [3,12,5,18,45]
bars = ('A','B','C','D','E')
y_pos = np.arange(len(bars))

plt.bar(y_pos, height)
plt.xticks(y_pos, bars)
plt.show()

# %%
df = pd.DataFrame ({
        'Group':  ['A', 'B', 'C', 'D', 'E'],
        'Value': [1,5,4,3,9]
})
df = df.sort_values(by=['Value'])

fig, ax = plt.subplots()
fig.set_size_inches(9,9)
ax.barh(y=df.Group, width=df.Value)
ax.set_title('A simple barplot')
# Out:
# Text(0.5, 1.0, 'A simple barplot')

# %%
plt.bar(y_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])
plt.xticks(y_pos, bars)
# Out:
# ([<matplotlib.axis.XTick at 0x1fe06e80f10>,
#   <matplotlib.axis.XTick at 0x1fe06e80ee0>,
#   <matplotlib.axis.XTick at 0x1fe06ed1dc0>,
#   <matplotlib.axis.XTick at 0x1fe06ee7e20>,
#   <matplotlib.axis.XTick at 0x1fe06eef910>],
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E')])

# %%
# color 및 edgecolor에 튜플형태로 총 4가지의 0이상 1이하의 float을 넣으면
# rgba(red,green,blue,alpha) 빨초파 그리고 투명도가 됨
plt.bar(y_pos, 
        height, 
        color=(.423,.1,.1,.5),
        edgecolor=(.1,.1,.723,.5))
plt.xticks(y_pos, bars)
# Out:
# ([<matplotlib.axis.XTick at 0x1fe08459e50>,
#   <matplotlib.axis.XTick at 0x1fe08478130>,
#   <matplotlib.axis.XTick at 0x1fe0849a940>,
#   <matplotlib.axis.XTick at 0x1fe084aaa30>,
#   <matplotlib.axis.XTick at 0x1fe084b4520>],
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E')])

# %%
x_pos = [0,1,5,8,9]
plt.bar(x_pos,height)
plt.xticks(x_pos,bars)
plt.show()

# %%
width = [0.1,0.2,3,1.5,0.3]
x_pos = [0,0.3,2,4.5,5.5]

plt.bar(x_pos, height, width=width)
plt.xticks(x_pos,bars)
plt.show()

# %%
bars = ('group1', 'group2', 'group3', 'group4', 'group5')
x_pos = np.arange(len(bars))

plt.bar(x_pos, height)
# ticks 색상도 변경 가능 / ticks 각도 변경 가능
plt.xticks(x_pos, bars, color='orange', rotation=90)
plt.yticks(color='orange')
# 제목 색상도 변경 가능 / 제목 각도도 변경 가능
plt.xlabel('category', 
           fontweight='bold', 
           color = 'orange', 
           fontsize='18',
           rotation=90)
plt.show()

# %%
barWidth = 0.3
bars1 = [10, 9, 2]
bars2 = [10.8, 9.5, 4.5]
yer1 = [0.5, 0.4, 0.5]
yer2 = [1, 0.7, 1]

r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.bar(r1, 
        bars1, 
        width = barWidth, 
        color = 'blue', 
        edgecolor = 'black', 
        yerr=yer1, 
        capsize=7, 
        label='poacee')

plt.bar(r2, 
        bars2, 
        width = barWidth, 
        color = 'cyan', 
        edgecolor = 'black', 
        yerr=yer2, 
        capsize=7, 
        label='sorgho')

plt.xticks([r + barWidth for r in range(len(bars1))], 
           ['cond_A', 'cond_B', 'cond_C'])
plt.ylabel('height')
plt.legend()
plt.show()

# %%
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3

r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3

plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Alone')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='With Himself')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='With other genotype')

plt.legend()

plt.xticks([r + barWidth for r in range(len(r4))], 
           ['DD', 'with himself', 'with DC', 'with Silur', 'DC', 'with himself', 'with DD', 'with Silur', 'Silur', 'with himself', 'with DD', 'with DC'], 
           rotation=90)

label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']

for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)

plt.subplots_adjust(bottom= 0.2, top = 0.98)
plt.show()

# %%
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")

plt.figure(figsize=(10, 7))
# ci는 없어지고 errorbar로 변경됨
sns.barplot(
    x="total_bill", 
    y="day", 
    data=tips, 
    estimator=sum, 
    errorbar=None,
    color='#69b3a2')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
plt.figure(figsize=(14, 10))

sns.barplot(
    y="total_bill", 
    x="day", 
    data=tips, 
    estimator=sum, 
    errorbar=None,
    color='#69b3a2')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(14, 10))
sns.barplot(
    x="total_bill", 
    y="day", 
    data=tips, 
    estimator=sum, 
    errorbar=None, 
    order=["Fri","Thur","Sun","Sat"], 
    color='#69b3a2'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
df = pd.DataFrame({
        'group': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
        'value': [1, 10, 39, 23, 3, 42, 12]
})
df = df.sort_values(['value'], ascending=False).reset_index(drop=True)

sns.barplot(
    x="value", 
    y="group", 
    data=df, 
    estimator=sum, 
    errorbar=None, 
    color='#69b3a2'
)
# Out:
# <Axes: xlabel='value', ylabel='group'>

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x="day", 
                 y="total_bill", 
                 data=tips, 
                 estimator=np.mean, 
                 errorbar=('ci',85), 
                 capsize=.2, 
                 color='lightblue')

# %%
rc('font', weight='bold')
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]

bars = np.add(bars1, bars2).tolist()
r = [0,1,2,3,4]

names = ['A','B','C','D','E']
barWidth = 1

plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)

plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
plt.show()

# %%
barWidth = 0.25

r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')

plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])

plt.legend()
plt.show()

# %%
r = [0,1,2,3,4]
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 
            'orangeBars': [5, 15, 5, 10, 15],
            'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)

totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]

barWidth = 0.85
names = ('A','B','C','D','E')

plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth)
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth)
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)

plt.xticks(r, names)
plt.xlabel("group")
plt.show()

# %%
# plt.bar 그릴 때, label을 명시한 뒤 legend 그리기
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth, label="group A")
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth, label="group B")
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth, label="group C")
 
plt.xticks(r, names)
plt.xlabel("group")

# bbox_to_anchor를 쓰면 바운딩 박스 밖에서 범례를 나타낸다
plt.legend(loc='upper left', 
           bbox_to_anchor=(1,1), 
           ncol=1)
plt.show()

# %%
plt.figure(figsize=(8, 8))

sns.barplot(x="day", 
            y="total_bill", 
            hue="smoker", 
            data=tips, 
            errorbar=None)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x="sex", 
            y="total_bill",
            hue="smoker", 
            col="day",
            data=tips, 
            kind="bar",
            height=4, 
            aspect=.7)

# %%
colors = ["#69b3a2", "#4374B3"]
sns.set_palette(sns.color_palette(colors))

plt.figure(figsize=(10, 10))

ax = sns.barplot(
    x="day", 
    y="total_bill", 
    hue="smoker", 
    data=tips, 
    errorbar=None
    )

ax.set_title("Smokers have bigger bills")
ax.set_ylabel("Bill value")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
total = tips.groupby('day')['total_bill'].sum().reset_index()

# darkblue로 전체를 그리고
bar1 = sns.barplot(x="day",  
                   y="total_bill", 
                   data=total, 
                   color='darkblue')

smoker = tips[tips.smoker=='Yes']

# 흡연자를 lightblue로 덮는다
bar2 = sns.barplot(x="day", 
                   y="total_bill", 
                   data=smoker, 
                   estimator=sum, 
                   errorbar=None,  
                   color='lightblue')


top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

plt.show()

# %%
total = tips.groupby('day')['total_bill'].sum().reset_index()
smoker = tips[tips.smoker=='Yes'].groupby('day')['total_bill'].sum().reset_index()

# 비율 만들기 목금토일 
smoker['total_bill'] = [i / j * 100 for i,j in zip(smoker['total_bill'], total['total_bill'])]
# A / A를 한 뒤 100 곱한 값이라 결국 100%가 나옴
total['total_bill'] = [i / j * 100 for i,j in zip(total['total_bill'], total['total_bill'])]

bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, color='lightblue')


top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar], bbox_to_anchor=(1,1))

plt.show()
