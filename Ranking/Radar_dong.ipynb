# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from math import pi

df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

categories=list(df)[1:]     # ['var1', 'var2', 'var3', 'var4', 'var5']
N = len(categories)         # 5

values=df.loc[0].drop('group').values.flatten().tolist()        # [38.0, 29, 8, 7, 28]
values += values[:1]                                            # [38.0, 29, 8, 7, 28, 38.0]
#values

angles = [n / float(N) * 2 * pi for n in range(N)]     # [0.0, 1.2566370614359172, 2.5132741228718345, 3.7699111843077517, 5.026548245743669]
angles += angles[:1]                                   # [0.0, 1.2566370614359172, 2.5132741228718345, 3.7699111843077517, 5.026548245743669, 0.0]
#angles

sns.set(style="white")
plt.figure(figsize=(10, 10))

ax = plt.subplot(111, polar=True)           # Polar Coordinate를 그리기 위한 ax 생성

plt.xticks(angles[:-1], categories, color='red', size=15)       # x축 설정
 
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=10) # 기준 값 표시
plt.ylim(0,40)
 
ax.plot(angles, values, linewidth=1, linestyle='solid')         # 도형 그리기
 
ax.fill(angles, values, 'b', alpha=0.1)                         # 도형 채우기

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi

df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

categories=list(df)[1:]
N = len(categories)
 
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)
 
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
plt.xticks(angles[:-1], categories)
 
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)

values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

plt.show()
