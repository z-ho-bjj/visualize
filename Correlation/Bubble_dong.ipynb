# %%
# 버블차트
#!pip install gapminder
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder  import gapminder

data = gapminder.loc[gapminder.year == 2007]

sns.scatterplot(data=data,
                x="gdpPercap",
                y="lifeExp",
                size="pop",
                legend=False,
                sizes=(20, 2000)
                )

plt.show()

# %%
# 기본 버블차트
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder

plt.rcParams['figure.figsize'] = [8, 8]

data = gapminder.loc[gapminder.year == 2007]

sns.scatterplot(data=data,
                x="gdpPercap",          # x축
                y="lifeExp",            # y축
                size="pop",             # 버블 종류
                legend=False,           # 범례
                sizes=(20, 2000)
                )

plt.show()

# %%
# 거품크기
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder

data = gapminder.loc[gapminder.year == 2007]

sns.scatterplot(data=data,
                x="gdpPercap",          # x축
                y="lifeExp",            # y축
                size="pop",             # 버블 종류
                alpha=0.5,              # 투명도
                sizes=(20, 800)         # 버블크기
                )

plt.show()

# %%
# 버블색상
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder

data = gapminder.loc[gapminder.year == 2007]

sns.scatterplot(data=data,
                x="gdpPercap",          # x축
                y="lifeExp",            # y축
                size="pop",             # 버블 종류
                hue="continent",        # 그룹
                alpha=0.5,              # 투명도
                sizes=(20, 800)         # 버블크기
                )

plt.show()

# %%
# 기타 제어
sns.set_style("darkgrid")

sns.scatterplot(data=data,
                x="gdpPercap",          # x축
                y="lifeExp",            # y축
                size="pop",             # 버블 종류
                hue="continent",        # 그룹
                palette="viridis",      # 색상 표현
                alpha=0.5,              # 투명도
                sizes=(10, 1000)        # 버블크기
                )

plt.xlabel("Gdp per Capita")
plt.ylabel("Life Expectancy")

plt.show()

# %%
# matplotlib: 기본 버블차트
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

plt.scatter(x,
            y,
            s=z*1000,       # 버블 크기
            alpha=0.5       # 투명도
            )

plt.show()

# %%
# 색상
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

plt.scatter(x,
            y,
            s=z*1000,       # 버블 크기
            c="red",        # 버블 색상
            alpha=0.5       # 투명도
            )

plt.show()

# %%
# 모양
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

plt.scatter(x,
            y,
            s=z*1000,       # 버블 크기
            c="red",        # 버블 색상
            marker="D",     # 버블 모양
            alpha=0.5       # 투명도
            )

plt.show()

# %%
# 가장자리 굵기
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

plt.scatter(x,
            y,
            s=z*1000,       # 버블 크기
            c="green",      # 버블 색상
            marker="D",     # 버블 모양
            alpha=0.5,      # 투명도
            linewidths=6    # 가장자리 굵기
            )

plt.show()

# %%
# seaborn 스타일 반영
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

# seaborn 스타일 반영
sns.set_theme(style="white")

plt.scatter(x,
            y,
            s=z*1000,       # 버블 크기
            c="green",      # 버블 색상
            marker="D",     # 버블 모양
            alpha=0.5,      # 투명도
            linewidths=6    # 가장자리 굵기
            )

plt.show()

# %%
# 버블차트 4차원(색상) 표현
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.random.rand(15)
y = x+np.random.rand(15)
z = x+np.random.rand(15)
z = z*z

plt.scatter(x,                  # x 좌표값
            y,                  # y 좌표값
            s=z * 2000,         # 점 크기
            c=x,                # 색상 (x 값을 기준으로 색상 설정)
            cmap="Blues",       # 컬러맵 설정 (팔레트로 Blues 사용)
            alpha=0.4,          # 점의 투명도 (0에 가까울수록 투명, 1에 가까울수록 불투명)
            edgecolors="grey",  # 점의 테두리 색상 설정
            linewidth=2         # 점의 테두리 두께 설정
            )

plt.xlabel("the X axis")
plt.ylabel("the Y axis")
plt.title("A colored bubble plot")

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/gapminderData.csv')

data['continent']=pd.Categorical(data['continent'])

plt.figure(figsize=(10, 10))

data1952 = data[ data.year == 1952 ]

plt.scatter(
    x = data1952['lifeExp'], 
    y = data1952['gdpPercap'], 
    s=data1952['pop']/50000, 
    c=data1952['continent'].cat.codes, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2)
 
# Add titles (main and on axis)
plt.yscale('log')
plt.xlabel("Life Expectancy")
plt.ylabel("GDP per Capita")
plt.title("Year 1952")
plt.ylim(0,50000)
plt.xlim(30, 75)
# Out:
# C:\Users\tjehd\AppData\Local\Temp/ipykernel_11728/1883000381.py:27: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0,50000)
# (30.0, 75.0)
