# %%
# 기본 네트워크 차트
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')
 
nx.draw(G, with_labels=True)
plt.show()

# %%
# 노드
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

nx.draw(G,
        with_labels=True,       # 레이블 표시
        node_size=1500,         # 노드 크기
        node_color="skyblue",   # 노드 색상
        node_shape="s",         # 노드 모양
        alpha=0.5,              # 투명도
        linewidths=10           # 노드 테두리 굵기
        )
plt.show()

# %%
# 폰트
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

nx.draw(G,
        with_labels=True,       # 레이블 표시
        node_size=1500,         # 노드 크기
        node_color="skyblue",   # 노드 색상
        node_shape="s",         # 노드 모양
        alpha=0.5,              # 투명도
        linewidths=10,          # 노드 테두리 굵기
        font_size=25,           # 폰트 크기
        font_color="green",     # 폰트 색상
        font_weight="bold"      # 폰트 굵기
        )
plt.show()

# %%
# 엣지
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

nx.draw(G,
        with_labels=True,       # 레이블 표시
        node_size=1500,         # 노드 크기
        node_color="skyblue",   # 노드 색상
        node_shape="s",         # 노드 모양
        alpha=0.5,              # 투명도
        linewidths=10,           # 노드 테두리 굵기
        font_size=25,           # 폰트 크기
        font_color="green",     # 폰트 색상
        font_weight="bold",     # 폰트 굵기
        edge_color="red",   # 엣지 색상
        style="solid"           # 엣지 스타일
        )
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

nx.draw(G,
        with_labels=True,       # 레이블 표시
        node_size=1500,         # 노드 크기
        node_color="skyblue",   # 노드 색상
        node_shape="o",         # 노드 모양
        alpha=0.5,              # 투명도
        linewidths=4,           # 노드 테두리 굵기
        font_size=25,           # 폰트 크기
        font_color="grey",      # 폰트 색상
        font_weight="bold",     # 폰트 굵기
        width=2,                # 엣지 굵기
        edge_color="grey",      # 엣지 색상
        style="solid"           # 엣지 스타일
        )
plt.show()

# %%
# 노드의 최적의 위치 계산
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')
 
# Fruchterman Reingold
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.fruchterman_reingold_layout(G))
plt.title("fruchterman_reingold")
plt.show()
 
# Circular
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.circular_layout(G))
plt.title("circular")
plt.show()
 
# Random
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.random_layout(G))
plt.title("random")
plt.show()
 
# Spectral
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spectral_layout(G))
plt.title("spectral")
plt.show()
 
# Spring
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spring_layout(G))
plt.title("spring")
plt.show()

# %%
# 화살표
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

# 화살표 표시
nx.draw(G,
        with_labels=True,
        node_size=1500,
        alpha=0.3,
        arrows=True             # 화살표
        )
plt.title("Directed")
plt.show()

# %%
# 배경색
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})
 
G=nx.from_pandas_edgelist(df, 'from', 'to')

fig = plt.figure()
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color='white')
fig.set_facecolor("#00000F")            # 배경색 지정

# %%
#! pip install netgraph
import matplotlib.pyplot as plt
import networkx as nx
from netgraph import Graph

partition_sizes = [10, 20, 30, 40]
g = nx.random_partition_graph(partition_sizes, 0.5, 0.1)

# %%
# %%capture --no-display
Graph(g)

# %%
plt.rcParams['axes.unicode_minus'] = False

node_to_community = dict()
node = 0
for community_id, size in enumerate(partition_sizes):
    for _ in range(size):
        node_to_community[node] = community_id
        node += 1

community_to_color = {
    0 : 'tab:blue',
    1 : 'tab:orange',
    2 : 'tab:green',
    3 : 'tab:red',
}
node_color = {node: community_to_color[community_id] \
              for node, community_id in node_to_community.items()}

fig, ax = plt.subplots()

Graph(g,
      node_color=node_color,
      node_edge_width=0,
      edge_width=0.1,
      edge_alpha=0.5,
      node_layout='community', node_layout_kwargs=dict(node_to_community=node_to_community),
      ax=ax,
)


plt.show()

# %%
# 노드 색상 매핑
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})

carac = pd.DataFrame({'ID':['A', 'B', 'C','D','E'],
                      'myvalue':['123','25','76','12','34']})

G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

G.nodes()

carac = carac.set_index('ID')
carac = carac.reindex(G.nodes())

nx.draw(G, with_labels=True, node_color=carac['myvalue'].astype(int), cmap=plt.cm.Blues)
plt.show()

# %%
# 노드 색상 매핑
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C']})

carac = pd.DataFrame({'ID':['A', 'B', 'C','D','E'],
                      'myvalue':['123','25','76','12','34']})

G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

G.nodes()

carac['myvalue']=pd.Categorical(carac['myvalue'])
carac['myvalue'].cat.codes

nx.draw(G, with_labels=True, node_color=carac['myvalue'].cat.codes, cmap=plt.cm.Set1, node_size=1500)
plt.show()

# %%
# 엣지 색상 매핑: 수치형
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C'],
                   'value':[1, 10, 5, 5]})

G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'], width=10.0, edge_cmap=plt.cm.Blues)

# %%
# 엣지 색상 매핑: 범주형
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
df = pd.DataFrame({'from':['A', 'B', 'C','A'],
                   'to':['D', 'A', 'E','C'],
                   'value':['typeA', 'typeA', 'typeB', 'typeB']})
 
df['value']=pd.Categorical(df['value'])
df['value'].cat.codes
 
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )
 
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'].cat.codes, width=10.0, edge_cmap=plt.cm.Set2)

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

ind1=[5,10,3,4,8,10,12,1,9,4]
ind5=[1,1,13,4,18,5,2,11,3,8]
df = pd.DataFrame({'A':ind1,
                   'B':ind1 + np.random.randint(10, size=(10)),
                   'C':ind1 + np.random.randint(10, size=(10)),
                   'D':ind1 + np.random.randint(5, size=(10)),
                   'E':ind1 + np.random.randint(5, size=(10)),
                   'F':ind5,
                   'G':ind5 + np.random.randint(5, size=(10)),
                   'H':ind5 + np.random.randint(5, size=(10)),
                   'I':ind5 + np.random.randint(5, size=(10)),
                   'J':ind5 + np.random.randint(5, size=(10))})

corr = df.corr()

links = corr.stack().reset_index()
links.columns = ['var1', 'var2', 'value']

links_filtered=links.loc[ (links['value'] > -1.) & (links['var1'] != links['var2']) ]

G=nx.from_pandas_edgelist(links_filtered, 'var1', 'var2')

nx.draw(G, with_labels=True, node_color='orange', node_size=400, edge_color='black', linewidths=1, font_size=15)

# %%
corr
# Out:
#           A         B         C         D         E         F         G  \
# A  1.000000  0.642741  0.921778  0.936822  0.905405 -0.409401 -0.330664
# B  0.642741  1.000000  0.565961  0.627982  0.554912 -0.202032 -0.085097
# C  0.921778  0.565961  1.000000  0.827774  0.821971 -0.540743 -0.449148
# D  0.936822  0.627982  0.827774  1.000000  0.845394 -0.193103 -0.129475
# E  0.905405  0.554912  0.821971  0.845394  1.000000 -0.350462 -0.281609
# F -0.409401 -0.202032 -0.540743 -0.193103 -0.350462  1.000000  0.975667
# G -0.330664 -0.085097 -0.449148 -0.129475 -0.281609  0.975667  1.000000
# H -0.393985 -0.166436 -0.552594 -0.160944 -0.375730  0.968458  0.912473
# I -0.339607 -0.079125 -0.455471 -0.116876 -0.249030  0.980189  0.988238
# J -0.262429 -0.164366 -0.377043 -0.059603 -0.228674  0.975721  0.972692
#
#           H         I         J
# A -0.393985 -0.339607 -0.262429
# B -0.166436 -0.079125 -0.164366
# C -0.552594 -0.455471 -0.377043
# D -0.160944 -0.116876 -0.059603
# E -0.375730 -0.249030 -0.228674
# F  0.968458  0.980189  0.975721
# G  0.912473  0.988238  0.972692
# H  1.000000  0.926489  0.934366
# I  0.926489  1.000000  0.965032
# J  0.934366  0.965032  1.000000

# %%
links.columns
# Out:
# Index(['var1', 'var2', 'value'], dtype='object')
