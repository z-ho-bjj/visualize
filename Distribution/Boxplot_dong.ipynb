# %%
import seaborn as sns

df = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"]
            )
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# data
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df=a.append(b).append(c).append(d).append(e)

plt.rcParams['axes.unicode_minus'] = False    # 음수 부로 표시를 위한 설정
sns.boxplot(x='group', y='value', data=df)
plt.show()

# %%
# 관측값 표기
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# data
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df=a.append(b).append(c).append(d).append(e)

# 상자그림
ax = sns.boxplot(x='group',
                 y='value',
                 data=df
                 )
# stripplot
ax = sns.stripplot(x='group',
                   y='value',
                   data=df,
                   color="orange",
                   jitter=0.2,
                   size=2.5
                   )

plt.rcParams['axes.unicode_minus'] = False    # 음수 부로 표시를 위한 설정
plt.title("Boxplot with jitter", loc="left")
plt.show()

# %%
# violinplot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# data
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df=a.append(b).append(c).append(d).append(e)

# violin
sns.violinplot(x='group',
               y='value',
               data=df
               )

plt.title("Violin plot", loc="left")
plt.show()

# %%
# 관찰수 표시
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# data
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df=a.append(b).append(c).append(d).append(e)

# boxplot
ax = sns.boxplot(x="group",
                 y="value",
                 data=df
                 )

# 관찰수
medians = df.groupby(['group'])['value'].median().values
nobs = df.groupby("group").size().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]

# 그래프 위에 관찰수 나타내기
pos = range(len(nobs))
for tick, label in zip(pos, ax.get_xticklabels()):
    plt.text(pos[tick],
             medians[tick] + 0.4,
             nobs[tick],
             horizontalalignment='center',
             size='medium',
             color='w',
             weight='semibold'
             )

plt.rcParams['axes.unicode_minus'] = False    # 음수 부로 표시를 위한 설정
plt.title("Boxplot with number of observation", loc="left")
plt.show()

# %%
# 색상제어
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            palette="Oranges"        # 그룹별 구별 색상
            )
plt.show()

# %%
# 균일한 색상
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            #palette="Oranges"        # 그룹별 구별 색상
            color='skyblue'          # 균일한 색상
            )
plt.show()

# %%
# 그룹별 색상
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

# 그룹별 색상 지정
my_pal = {"versicolor":"g", "setosa":"b", "virginica":"m"}

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            palette=my_pal        # 그룹별 구별 색상
            )
plt.show()

# %%
# 특정 그룹 강조
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

# 특정 그룹 강조
my_pal = {species: "r" if species == "versicolor" else "b" for species in df.species.unique()}

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            palette=my_pal        # 그룹별 구별 색상
            )
plt.show()

# %%
# 투명도 추가
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

ax = sns.boxplot(x='species',
                 y='sepal_length',
                 data=df
                 )
# 투명도 적용
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .3))

plt.show()

# %%
# 하위그룹
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('tips')

sns.boxplot(x="day",
            y="total_bill",
            hue="smoker",
            data=df,
            palette="Set1",
            width=0.5
            )
plt.show()

# %%
# 상자 정렬
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

# 정렬 값 정의
my_order = df.groupby(by=["species"])["sepal_length"].median().iloc[::-1].index

# 상자그림
sns.boxplot(x='species',
            y='sepal_length',
            data=df,
            order=my_order
            )

plt.show()

# %%
# 상자그림 안에 분포 표시(jitter)
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

#상자그림
ax = sns.boxplot(x='species',
                 y='sepal_length',
                 data=df
                 )

# 분포(jitter)
ax = sns.swarmplot(x='species',
                   y='sepal_length',
                   data=df,
                   color="grey"
                   )

plt.show()

# %%
# 관측치 수 표기
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

ax = sns.boxplot(x="species",
                 y="sepal_length",
                 data=df
                 )

# 관측치수
medians = df.groupby(['species'])['sepal_length'].median().values
nobs = df['species'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]

# add
pos = range(len(nobs))
for tick, label in zip(pos, ax.get_xticklabels()):
    ax.text(pos[tick],
            medians[tick] + 0.03,            # 관측치 위치 조정
            nobs[tick],
            horizontalalignment='center',
            size='x-small',
            color='w',
            weight='semibold')

plt.show()

# %%
# 상자 테두리 조정
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            linewidth=5                 # 상자 테두리 굵기
            )

plt.show()

# %%
# 노치
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
sd = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            notch=True                  # 노치 설정
            )
plt.show()

# %%
# 상자 크기 조정
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
df = sns.load_dataset('iris')

sns.boxplot(x=df["species"],
            y=df["sepal_length"],
            width=0.2                   # 상자 폭 조정
            )
plt.show()
